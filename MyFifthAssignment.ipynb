# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
import pandas as pd

df = pd.read_csv('NewChurn.csv', index_col='customerID', )
df
# Out:
#             tenure PhoneService        Contract              PaymentMethod  \
# customerID
# 7590-VHVEG       1           No  Month-to-month           Electronic check
# 5575-GNVDE      34          Yes        One year               Mailed check
# 3668-QPYBK       2          Yes  Month-to-month               Mailed check
# 7795-CFOCW      45           No        One year  Bank transfer (automatic)
# 9237-HQITU       2          Yes  Month-to-month           Electronic check
# ...            ...          ...             ...                        ...
# 6840-RESVB      24          Yes        One year               Mailed check
# 2234-XADUH      72          Yes        One year    Credit card (automatic)
# 4801-JZAZL      11           No  Month-to-month           Electronic check
# 8361-LTMKD       4          Yes  Month-to-month               Mailed check
# 3186-AJIEK      66          Yes        Two year  Bank transfer (automatic)
#
#             MonthlyCharges  TotalCharges Churn  Total_Charges_ratio  \
# customerID
# 7590-VHVEG           29.85         29.85    No            29.850000
# 5575-GNVDE           56.95       1889.50    No            55.573529
# 3668-QPYBK           53.85        108.15   Yes            54.075000
# 7795-CFOCW           42.30       1840.75    No            40.905556
# 9237-HQITU           70.70        151.65   Yes            75.825000
# ...                    ...           ...   ...                  ...
# 6840-RESVB           84.80       1990.50    No            82.937500
# 2234-XADUH          103.20       7362.90    No           102.262500
# 4801-JZAZL           29.60        346.45    No            31.495455
# 8361-LTMKD           74.40        306.60   Yes            76.650000
# 3186-AJIEK          105.65       6844.50    No           103.704545
#
#             Monthly_Charges_ratio  Average_Monthly_Charges_ratio
# customerID
# 7590-VHVEG               1.000000                      29.850000
# 5575-GNVDE               0.030140                      55.573529
# 3668-QPYBK               0.497920                      54.075000
# 7795-CFOCW               0.022980                      40.905556
# 9237-HQITU               0.466205                      75.825000
# ...                           ...                            ...
# 6840-RESVB               0.042602                      82.937500
# 2234-XADUH               0.014016                     102.262500
# 4801-JZAZL               0.085438                      31.495455
# 8361-LTMKD               0.242661                      76.650000
# 3186-AJIEK               0.015436                     103.704545
#
# [7043 rows x 10 columns]

# %%
from pycaret.classification import *

# %%
automl = setup(df, target='Churn')
# Out:
# <style type="text/css">
# #T_f07db_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f07db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f07db_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f07db_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f07db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f07db_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f07db_row0_col1" class="data row0 col1" >5147</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f07db_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f07db_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f07db_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f07db_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f07db_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_f07db_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f07db_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_f07db_row4_col1" class="data row4 col1" >(7043, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f07db_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_f07db_row5_col1" class="data row5 col1" >(7043, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f07db_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_f07db_row6_col1" class="data row6 col1" >(4930, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f07db_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_f07db_row7_col1" class="data row7 col1" >(2113, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f07db_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_f07db_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f07db_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_f07db_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f07db_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_f07db_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f07db_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_f07db_row11_col1" class="data row11 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f07db_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_f07db_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f07db_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_f07db_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f07db_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_f07db_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f07db_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_f07db_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f07db_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_f07db_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f07db_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_f07db_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f07db_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_f07db_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f07db_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_f07db_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f07db_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_f07db_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f07db_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_f07db_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f07db_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_f07db_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f07db_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_f07db_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f07db_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f07db_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_f07db_row24_col1" class="data row24 col1" >5f34</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_9f016 th {
#   text-align: left;
# }
# #T_9f016_row0_col0, #T_9f016_row0_col4, #T_9f016_row0_col5, #T_9f016_row0_col6, #T_9f016_row0_col7, #T_9f016_row1_col0, #T_9f016_row1_col1, #T_9f016_row1_col2, #T_9f016_row1_col3, #T_9f016_row1_col4, #T_9f016_row1_col7, #T_9f016_row2_col0, #T_9f016_row2_col1, #T_9f016_row2_col2, #T_9f016_row2_col3, #T_9f016_row2_col4, #T_9f016_row2_col5, #T_9f016_row2_col6, #T_9f016_row2_col7, #T_9f016_row3_col0, #T_9f016_row3_col1, #T_9f016_row3_col2, #T_9f016_row3_col3, #T_9f016_row3_col4, #T_9f016_row3_col5, #T_9f016_row3_col6, #T_9f016_row3_col7, #T_9f016_row4_col0, #T_9f016_row4_col1, #T_9f016_row4_col2, #T_9f016_row4_col3, #T_9f016_row4_col4, #T_9f016_row4_col5, #T_9f016_row4_col6, #T_9f016_row4_col7, #T_9f016_row5_col0, #T_9f016_row5_col1, #T_9f016_row5_col2, #T_9f016_row5_col3, #T_9f016_row5_col4, #T_9f016_row5_col5, #T_9f016_row5_col6, #T_9f016_row5_col7, #T_9f016_row6_col0, #T_9f016_row6_col1, #T_9f016_row6_col2, #T_9f016_row6_col3, #T_9f016_row6_col4, #T_9f016_row6_col5, #T_9f016_row6_col6, #T_9f016_row6_col7, #T_9f016_row7_col0, #T_9f016_row7_col1, #T_9f016_row7_col2, #T_9f016_row7_col3, #T_9f016_row7_col4, #T_9f016_row7_col5, #T_9f016_row7_col6, #T_9f016_row7_col7, #T_9f016_row8_col0, #T_9f016_row8_col1, #T_9f016_row8_col2, #T_9f016_row8_col3, #T_9f016_row8_col4, #T_9f016_row8_col5, #T_9f016_row8_col6, #T_9f016_row8_col7, #T_9f016_row9_col0, #T_9f016_row9_col1, #T_9f016_row9_col2, #T_9f016_row9_col3, #T_9f016_row9_col4, #T_9f016_row9_col5, #T_9f016_row9_col6, #T_9f016_row9_col7, #T_9f016_row10_col0, #T_9f016_row10_col1, #T_9f016_row10_col2, #T_9f016_row10_col3, #T_9f016_row10_col4, #T_9f016_row10_col5, #T_9f016_row10_col6, #T_9f016_row10_col7, #T_9f016_row11_col0, #T_9f016_row11_col1, #T_9f016_row11_col2, #T_9f016_row11_col3, #T_9f016_row11_col5, #T_9f016_row11_col6, #T_9f016_row12_col0, #T_9f016_row12_col1, #T_9f016_row12_col2, #T_9f016_row12_col3, #T_9f016_row12_col4, #T_9f016_row12_col5, #T_9f016_row12_col6, #T_9f016_row12_col7, #T_9f016_row13_col0, #T_9f016_row13_col1, #T_9f016_row13_col2, #T_9f016_row13_col3, #T_9f016_row13_col4, #T_9f016_row13_col5, #T_9f016_row13_col6, #T_9f016_row13_col7 {
#   text-align: left;
# }
# #T_9f016_row0_col1, #T_9f016_row0_col2, #T_9f016_row0_col3, #T_9f016_row1_col5, #T_9f016_row1_col6, #T_9f016_row11_col4, #T_9f016_row11_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9f016_row0_col8, #T_9f016_row1_col8, #T_9f016_row3_col8, #T_9f016_row4_col8, #T_9f016_row5_col8, #T_9f016_row6_col8, #T_9f016_row7_col8, #T_9f016_row8_col8, #T_9f016_row10_col8, #T_9f016_row12_col8, #T_9f016_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9f016_row2_col8, #T_9f016_row9_col8, #T_9f016_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9f016">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f016_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9f016_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9f016_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9f016_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9f016_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9f016_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9f016_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9f016_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9f016_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f016_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_9f016_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_9f016_row0_col1" class="data row0 col1" >0.7961</td>
#       <td id="T_9f016_row0_col2" class="data row0 col2" >0.8380</td>
#       <td id="T_9f016_row0_col3" class="data row0 col3" >0.7961</td>
#       <td id="T_9f016_row0_col4" class="data row0 col4" >0.7853</td>
#       <td id="T_9f016_row0_col5" class="data row0 col5" >0.7867</td>
#       <td id="T_9f016_row0_col6" class="data row0 col6" >0.4351</td>
#       <td id="T_9f016_row0_col7" class="data row0 col7" >0.4421</td>
#       <td id="T_9f016_row0_col8" class="data row0 col8" >0.1530</td>
#     </tr>
#     <tr>
#       <th id="T_9f016_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_9f016_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_9f016_row1_col1" class="data row1 col1" >0.7953</td>
#       <td id="T_9f016_row1_col2" class="data row1 col2" >0.8350</td>
#       <td id="T_9f016_row1_col3" class="data row1 col3" >0.7953</td>
#       <td id="T_9f016_row1_col4" class="data row1 col4" >0.7848</td>
#       <td id="T_9f016_row1_col5" class="data row1 col5" >0.7868</td>
#       <td id="T_9f016_row1_col6" class="data row1 col6" >0.4364</td>
#       <td id="T_9f016_row1_col7" class="data row1 col7" >0.4422</td>
#       <td id="T_9f016_row1_col8" class="data row1 col8" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_9f016_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_9f016_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_9f016_row2_col1" class="data row2 col1" >0.7933</td>
#       <td id="T_9f016_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_9f016_row2_col3" class="data row2 col3" >0.7933</td>
#       <td id="T_9f016_row2_col4" class="data row2 col4" >0.7799</td>
#       <td id="T_9f016_row2_col5" class="data row2 col5" >0.7796</td>
#       <td id="T_9f016_row2_col6" class="data row2 col6" >0.4110</td>
#       <td id="T_9f016_row2_col7" class="data row2 col7" >0.4230</td>
#       <td id="T_9f016_row2_col8" class="data row2 col8" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_9f016_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_9f016_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_9f016_row3_col1" class="data row3 col1" >0.7911</td>
#       <td id="T_9f016_row3_col2" class="data row3 col2" >0.8377</td>
#       <td id="T_9f016_row3_col3" class="data row3 col3" >0.7911</td>
#       <td id="T_9f016_row3_col4" class="data row3 col4" >0.7807</td>
#       <td id="T_9f016_row3_col5" class="data row3 col5" >0.7830</td>
#       <td id="T_9f016_row3_col6" class="data row3 col6" >0.4272</td>
#       <td id="T_9f016_row3_col7" class="data row3 col7" >0.4322</td>
#       <td id="T_9f016_row3_col8" class="data row3 col8" >0.2850</td>
#     </tr>
#     <tr>
#       <th id="T_9f016_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_9f016_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_9f016_row4_col1" class="data row4 col1" >0.7911</td>
#       <td id="T_9f016_row4_col2" class="data row4 col2" >0.8325</td>
#       <td id="T_9f016_row4_col3" class="data row4 col3" >0.7911</td>
#       <td id="T_9f016_row4_col4" class="data row4 col4" >0.7800</td>
#       <td id="T_9f016_row4_col5" class="data row4 col5" >0.7819</td>
#       <td id="T_9f016_row4_col6" class="data row4 col6" >0.4230</td>
#       <td id="T_9f016_row4_col7" class="data row4 col7" >0.4293</td>
#       <td id="T_9f016_row4_col8" class="data row4 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_9f016_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_9f016_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9f016_row5_col1" class="data row5 col1" >0.7886</td>
#       <td id="T_9f016_row5_col2" class="data row5 col2" >0.8255</td>
#       <td id="T_9f016_row5_col3" class="data row5 col3" >0.7886</td>
#       <td id="T_9f016_row5_col4" class="data row5 col4" >0.7787</td>
#       <td id="T_9f016_row5_col5" class="data row5 col5" >0.7812</td>
#       <td id="T_9f016_row5_col6" class="data row5 col6" >0.4235</td>
#       <td id="T_9f016_row5_col7" class="data row5 col7" >0.4278</td>

# %%
best_model
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=5147, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
df.iloc[-2:-1]
# Out:
#             tenure PhoneService        Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4          Yes  Month-to-month  Mailed check            74.4
#
#             TotalCharges Churn  Total_Charges_ratio  Monthly_Charges_ratio  \
# customerID
# 8361-LTMKD         306.6   Yes                76.65               0.242661
#
#             Average_Monthly_Charges_ratio
# customerID
# 8361-LTMKD                          76.65

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_0066d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0066d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0066d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0066d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0066d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0066d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0066d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0066d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0066d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0066d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0066d_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0066d_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_0066d_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0066d_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_0066d_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_0066d_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_0066d_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_0066d_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             tenure PhoneService        Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4          Yes  Month-to-month  Mailed check       74.400002
#
#             TotalCharges  Total_Charges_ratio  Monthly_Charges_ratio  \
# customerID
# 8361-LTMKD    306.600006            76.650002               0.242661
#
#             Average_Monthly_Charges_ratio Churn prediction_label  \
# customerID
# 8361-LTMKD                      76.650002   Yes              Yes
#
#             prediction_score
# customerID
# 8361-LTMKD            0.5264

# %%
save_model(best_model, 'XGBoost')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'MonthlyCharges',
#                                               'TotalCharges',
#                                               'Total_Charges_ratio',
#                                               'Monthly_Charges_ratio',
#                                               'Average_Monthly_Charges_ratio'],
#                                      transformer=SimpleIm...
#                                              criterion='friedman_mse', init=None,
#                                              learning_rate=0.1, loss='log_loss',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              random_state=5147, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False))],
#           verbose=False),
#  'XGBoost.pkl')

# %%
import pickle
with open('XGBoost.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('XGBoost.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
loaded_lda = load_model('XGBoost')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_data=df.iloc[-2:-1]

# %%
predict_model(loaded_lda, new_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_afdc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afdc8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_afdc8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_afdc8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_afdc8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_afdc8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_afdc8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_afdc8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_afdc8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afdc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afdc8_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_afdc8_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_afdc8_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_afdc8_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_afdc8_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_afdc8_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_afdc8_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_afdc8_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             tenure PhoneService        Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4          Yes  Month-to-month  Mailed check       74.400002
#
#             TotalCharges  Total_Charges_ratio  Monthly_Charges_ratio  \
# customerID
# 8361-LTMKD    306.600006            76.650002               0.242661
#
#             Average_Monthly_Charges_ratio Churn prediction_label  \
# customerID
# 8361-LTMKD                      76.650002   Yes              Yes
#
#             prediction_score
# customerID
# 8361-LTMKD            0.5264

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# predict_churn.py

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
